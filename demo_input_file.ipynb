# %%
print("hello")
# Out:
# hello

# %%
import pandas as pd

# %%
df = pd.read_csv ('../orginal_sales_data_edit.csv')

# %%
df.head
# Out:
# <bound method NDFrame.head of       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#        ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %%
df["YEAR_ID"].values
# Out:
# array([2003, 2003, 2003, ..., 2005, 2005, 2005], dtype=int64)

# %%
df["YEAR_ID"] = df["YEAR_ID"].astype("int32")

# %%
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#        ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %%
df.shape
# Out:
# (2823, 27)

# %%
df["ADDRESSLINE2"].isna().sum()
# Out:
# 2521

# %%
df["ADDRESSLINE2"]
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#        ...
# 2818    NaN
# 2819    NaN
# 2820    NaN
# 2821    NaN
# 2822    NaN
# Name: ADDRESSLINE2, Length: 2823, dtype: object

# %%
df["ADDRESSLINE2"].fillna('unknown', inplace = True)

# %%
df["ADDRESSLINE2"]
# Out:
# 0       unknown
# 1       unknown
# 2       unknown
# 3       unknown
# 4       unknown
#          ...
# 2818    unknown
# 2819    unknown
# 2820    unknown
# 2821    unknown
# 2822    unknown
# Name: ADDRESSLINE2, Length: 2823, dtype: object

# %%
df["ADDRESSLINE2"].isna().sum()
# Out:
# 0

# %%
df["ADDRESSLINE2"]
# Out:
# 0       unknown
# 1       unknown
# 2       unknown
# 3       unknown
# 4       unknown
#          ...
# 2818    unknown
# 2819    unknown
# 2820    unknown
# 2821    unknown
# 2822    unknown
# Name: ADDRESSLINE2, Length: 2823, dtype: object

# %%
df["QUANTITYORDERED"]
# Out:
# 0       30
# 1       34
# 2       41
# 3       45
# 4       49
#         ..
# 2818    20
# 2819    29
# 2820    43
# 2821    34
# 2822    47
# Name: QUANTITYORDERED, Length: 2823, dtype: int64

# %%
df["QUANTITYORDERED"].values
# Out:
# array([30, 34, 41, ..., 43, 34, 47], dtype=int64)

# %%
df[["QUANTITYORDERED"]]
# Out:
#       QUANTITYORDERED
# 0                  30
# 1                  34
# 2                  41
# 3                  45
# 4                  49
# ...               ...
# 2818               20
# 2819               29
# 2820               43
# 2821               34
# 2822               47
#
# [2823 rows x 1 columns]

# %%
df[4:9]
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 4        10159               49     100.00               14  5205.27
# 5        10168               36      96.66                1  3479.76
# 6        10180               29      86.13                9  2497.77
# 7        10188               48     100.00                1  5512.32
# 8        10201               22      98.57                2  2168.54
#
#     ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 4  10/10/2003  Shipped       4        10     2003  ...
# 5  10/28/2003  Shipped       4        10     2003  ...
# 6  11/11/2003  Shipped       4        11     2003  ...
# 7  11/18/2003  Shipped       4        11     2003  ...
# 8   12/1/2003  Shipped       4        12     2003  ...
#
#                   ADDRESSLINE1  ADDRESSLINE2           CITY STATE POSTALCODE  \
# 4              7734 Strong St.       unknown  San Francisco    CA        NaN
# ...

# %%
df.loc[4:8]
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 4        10159               49     100.00               14  5205.27
# 5        10168               36      96.66                1  3479.76
# 6        10180               29      86.13                9  2497.77
# 7        10188               48     100.00                1  5512.32
# 8        10201               22      98.57                2  2168.54
#
#     ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 4  10/10/2003  Shipped       4        10     2003  ...
# 5  10/28/2003  Shipped       4        10     2003  ...
# 6  11/11/2003  Shipped       4        11     2003  ...
# 7  11/18/2003  Shipped       4        11     2003  ...
# 8   12/1/2003  Shipped       4        12     2003  ...
#
#                   ADDRESSLINE1  ADDRESSLINE2           CITY STATE POSTALCODE  \
# 4              7734 Strong St.       unknown  San Francisco    CA        NaN
# ...

# %%
df.iloc[4:8]
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 4        10159               49     100.00               14  5205.27
# 5        10168               36      96.66                1  3479.76
# 6        10180               29      86.13                9  2497.77
# 7        10188               48     100.00                1  5512.32
#
#     ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 4  10/10/2003  Shipped       4        10     2003  ...
# 5  10/28/2003  Shipped       4        10     2003  ...
# 6  11/11/2003  Shipped       4        11     2003  ...
# 7  11/18/2003  Shipped       4        11     2003  ...
#
#                   ADDRESSLINE1  ADDRESSLINE2           CITY STATE POSTALCODE  \
# 4              7734 Strong St.       unknown  San Francisco    CA        NaN
# 5            9408 Furth Circle       unknown     Burlingame    CA      94217
# 6      184, chausse de Tournai       unknown          Lille   NaN      59000
# ...

# %%
df.loc[1]
# Out:
# ORDERNUMBER                      10121
# QUANTITYORDERED                     34
# PRICEEACH                        81.35
# ORDERLINENUMBER                      5
# SALES                           2765.9
# ORDERDATE                     5/7/2003
# STATUS                         Shipped
# QTR_ID                               2
# MONTH_ID                             5
# YEAR_ID                           2003
# PRODUCTLINE                Motorcycles
# MSRP                                95
# PRODUCTCODE                   S10_1678
# CATEGORY                     Furniture
# SUBCATEGORY                    Cabinet
# CUSTOMERNAME        Reims Collectables
# PHONE                       26.47.1555
# ADDRESSLINE1        59 rue de l'Abbaye
# ADDRESSLINE2                   unknown
# CITY                             Reims
# STATE                              NaN
# POSTALCODE                       51100
# COUNTRY                         France
# TERRITORY                         EMEA
# ...

# %%
df.iloc[1]
# Out:
# ORDERNUMBER                      10121
# QUANTITYORDERED                     34
# PRICEEACH                        81.35
# ORDERLINENUMBER                      5
# SALES                           2765.9
# ORDERDATE                     5/7/2003
# STATUS                         Shipped
# QTR_ID                               2
# MONTH_ID                             5
# YEAR_ID                           2003
# PRODUCTLINE                Motorcycles
# MSRP                                95
# PRODUCTCODE                   S10_1678
# CATEGORY                     Furniture
# SUBCATEGORY                    Cabinet
# CUSTOMERNAME        Reims Collectables
# PHONE                       26.47.1555
# ADDRESSLINE1        59 rue de l'Abbaye
# ADDRESSLINE2                   unknown
# CITY                             Reims
# STATE                              NaN
# POSTALCODE                       51100
# COUNTRY                         France
# TERRITORY                         EMEA
# ...

# %%
df.loc[4:9,['QUANTITYORDERED','SALES']]
# Out:
#    QUANTITYORDERED    SALES
# 4               49  5205.27
# 5               36  3479.76
# 6               29  2497.77
# 7               48  5512.32
# 8               22  2168.54
# 9               41  4708.44

# %%
df.iloc[2:9, 4:7]
# Out:
#      SALES   ORDERDATE   STATUS
# 2  3884.34    7/1/2003  Shipped
# 3  3746.70   8/25/2003  Shipped
# 4  5205.27  10/10/2003  Shipped
# 5  3479.76  10/28/2003  Shipped
# 6  2497.77  11/11/2003  Shipped
# 7  5512.32  11/18/2003  Shipped
# 8  2168.54   12/1/2003  Shipped

# %%
df.loc[2]
# Out:
# ORDERNUMBER                                 10134
# QUANTITYORDERED                                41
# PRICEEACH                                   94.74
# ORDERLINENUMBER                                 2
# SALES                                     3884.34
# ORDERDATE                                7/1/2003
# STATUS                                    Shipped
# QTR_ID                                          3
# MONTH_ID                                        7
# YEAR_ID                                      2003
# PRODUCTLINE                           Motorcycles
# MSRP                                           95
# PRODUCTCODE                              S10_1678
# CATEGORY                                Furniture
# SUBCATEGORY                               Cabinet
# CUSTOMERNAME                      Lyon Souveniers
# PHONE                            +33 1 46 62 7555
# ADDRESSLINE1        27 rue du Colonel Pierre Avia
# ADDRESSLINE2                              unknown
# ...

# %%
df.iloc[:10]
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
# 5        10168               36      96.66                1  3479.76
# 6        10180               29      86.13                9  2497.77
# 7        10188               48     100.00                1  5512.32
# 8        10201               22      98.57                2  2168.54
# 9        10211               41     100.00               14  4708.44
#
#     ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0   2/24/2003  Shipped       1         2     2003  ...
# 1    5/7/2003  Shipped       2         5     2003  ...
# ...

# %%
df.loc[:10]
# Out:
#     ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0         10107               30      95.70                2  2871.00
# 1         10121               34      81.35                5  2765.90
# 2         10134               41      94.74                2  3884.34
# 3         10145               45      83.26                6  3746.70
# 4         10159               49     100.00               14  5205.27
# 5         10168               36      96.66                1  3479.76
# 6         10180               29      86.13                9  2497.77
# 7         10188               48     100.00                1  5512.32
# 8         10201               22      98.57                2  2168.54
# 9         10211               41     100.00               14  4708.44
# 10        10223               37     100.00                1  3965.66
#
#      ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0    2/24/2003  Shipped       1         2     2003  ...
# ...

# %%
df.sort_values(by = 'SALES', ascending= False)
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER     SALES  \
# 598         10407               76     100.00                2  14082.80
# 744         10322               50     100.00                6  12536.50
# 53          10424               50     100.00                6  12001.00
# 1062        10412               60     100.00                9  11887.80
# 104         10403               66     100.00                9  11886.60
# ...           ...              ...        ...              ...       ...
# 1818        10419               15      42.67                7    640.05
# 1551        10280               20      28.88               12    577.60
# 2044        10408               15      36.93                1    553.95
# 1287        10407                6      90.19                3    541.14
# 2249        10425               11      43.83                6    482.13
#
#       ORDERDATE      STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %%
df.sort_values(by= ['QUANTITYORDERED', 'PRICEEACH'],ascending= [ True, False])
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER     SALES  \
# 751         10409                6     100.00                2    785.64
# 1287        10407                6      90.19                3    541.14
# 315         10419               10     100.00               11   1092.20
# 907         10423               10      88.14                1    881.40
# 2507        10401               11     100.00                8   1135.31
# ...           ...              ...        ...              ...       ...
# 1995        10405               76     100.00                3  11739.70
# 1714        10407               76      94.50                6   7182.00
# 2689        10401               77      92.00                9   7084.00
# 2586        10401               85      88.75               10   7543.75
# 418         10405               97      93.28                5   9048.16
#
#       ORDERDATE      STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %%
df[df['SALES'] > 5000]
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 4           10159               49      100.0               14  5205.27
# 7           10188               48      100.0                1  5512.32
# 20          10341               41      100.0                9  7737.93
# 25          10417               66      100.0                2  7516.08
# 26          10103               26      100.0               11  5404.62
# ...           ...              ...        ...              ...      ...
# 2685        10361               44      100.0               10  5001.92
# 2686        10375               44      100.0               11  5208.72
# 2689        10401               77       92.0                9  7084.00
# 2715        10397               48      100.0                3  5192.64
# 2820        10386               43      100.0                4  5417.57
#
#        ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %%
df.loc[df['SALES'] > 5000]
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 4           10159               49      100.0               14  5205.27
# 7           10188               48      100.0                1  5512.32
# 20          10341               41      100.0                9  7737.93
# 25          10417               66      100.0                2  7516.08
# 26          10103               26      100.0               11  5404.62
# ...           ...              ...        ...              ...      ...
# 2685        10361               44      100.0               10  5001.92
# 2686        10375               44      100.0               11  5208.72
# 2689        10401               77       92.0                9  7084.00
# 2715        10397               48      100.0                3  5192.64
# 2820        10386               43      100.0                4  5417.57
#
#        ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %%
df[(df['SALES'] > 5000 ) & (df['QUANTITYORDERED'] > 50)]
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER     SALES  \
# 25          10417               66     100.00                2   7516.08
# 104         10403               66     100.00                9  11886.60
# 105         10417               56     100.00                4   9218.16
# 131         10400               64     100.00                9   9661.44
# 260         10341               55     100.00                8   8118.55
# 264         10403               66     100.00                6   8648.64
# 392         10412               54     100.00                5   5951.34
# 418         10405               97      93.28                5   9048.16
# 447         10424               54     100.00                5   7182.00
# 473         10406               61     100.00                3   8374.69
# 550         10407               59     100.00               11   7048.14
# 598         10407               76     100.00                2  14082.80
# ...

# %%
df.loc[(df['SALES'] > 5000 ) & (df['QUANTITYORDERED'] > 50)]
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER     SALES  \
# 25          10417               66     100.00                2   7516.08
# 104         10403               66     100.00                9  11886.60
# 105         10417               56     100.00                4   9218.16
# 131         10400               64     100.00                9   9661.44
# 260         10341               55     100.00                8   8118.55
# 264         10403               66     100.00                6   8648.64
# 392         10412               54     100.00                5   5951.34
# 418         10405               97      93.28                5   9048.16
# 447         10424               54     100.00                5   7182.00
# 473         10406               61     100.00                3   8374.69
# 550         10407               59     100.00               11   7048.14
# 598         10407               76     100.00                2  14082.80
# ...

# %%
df.loc[df['PRICEEACH'] < 100, 'FLAG'] = 'CHEAP'

# %%
df.loc[df['PRICEEACH'] >= 100, 'FLAG'] = 'EXPENSIVE'

# %%
df[['FLAG']]
# Out:
#            FLAG
# 0         CHEAP
# 1         CHEAP
# 2         CHEAP
# 3         CHEAP
# 4     EXPENSIVE
# ...         ...
# 2818  EXPENSIVE
# 2819  EXPENSIVE
# 2820  EXPENSIVE
# 2821      CHEAP
# 2822      CHEAP
#
# [2823 rows x 1 columns]

# %%
def foo(x):
    if x < 10:
        return 'BAD'
    elif x >= 10 and x < 50:
        return 'GOOD'
    else:
        return 'EXCELLENT'
df['WORTH'] = df[['QUANTITYORDERED']].applymap(foo)

# %%
df[['QUANTITYORDERED', 'WORTH']]
# Out:
#       QUANTITYORDERED WORTH
# 0                  30  GOOD
# 1                  34  GOOD
# 2                  41  GOOD
# 3                  45  GOOD
# 4                  49  GOOD
# ...               ...   ...
# 2818               20  GOOD
# 2819               29  GOOD
# 2820               43  GOOD
# 2821               34  GOOD
# 2822               47  GOOD
#
# [2823 rows x 2 columns]

# %%
dict_map = {1:'Q1', 2:'Q2',3:'Q3',4:'Q4'}
df['QTR_ID'] = df['QTR_ID'].map(dict_map)

# %%
df['QTR_ID']
# Out:
# 0       Q1
# 1       Q2
# 2       Q3
# 3       Q3
# 4       Q4
#         ..
# 2818    Q4
# 2819    Q1
# 2820    Q1
# 2821    Q1
# 2822    Q2
# Name: QTR_ID, Length: 2823, dtype: object

# %%
df[['QUANTITYORDERED', 'PRICEEACH', 'QTR_ID']].loc[df['YEAR_ID'] == 2003]
# Out:
#       QUANTITYORDERED  PRICEEACH QTR_ID
# 0                  30      95.70     Q1
# 1                  34      81.35     Q2
# 2                  41      94.74     Q3
# 3                  45      83.26     Q3
# 4                  49     100.00     Q4
# ...               ...        ...    ...
# 2801               50      60.06     Q3
# 2802               38      48.59     Q4
# 2803               40      50.23     Q4
# 2804               28      64.43     Q4
# 2805               42      50.23     Q4
#
# [1000 rows x 3 columns]

# %%
df.aggregate({'QUANTITYORDERED': ['sum', 'min'], 'PRICEEACH': ['mean', 'max', 'min','std'],
'SALES': ['mean','sum','std'],'CITY': ['count']})
# Out:
#        QUANTITYORDERED   PRICEEACH         SALES    CITY
# sum            99067.0         NaN  1.003263e+07     NaN
# min                6.0   26.880000           NaN     NaN
# mean               NaN   83.658544  3.553889e+03     NaN
# max                NaN  100.000000           NaN     NaN
# std                NaN   20.174277  1.841865e+03     NaN
# count              NaN         NaN           NaN  2823.0

# %%
df.groupby(['DEALSIZE'])['SALES'].agg(['sum','min'])
# Out:
#                  sum      min
# DEALSIZE
# Large     1302119.26  7016.31
# Medium    6087432.24  3002.40
# Small     2643077.35   482.13

# %%
df.aggregate({'SALES': ['sum','min']})
# Out:
#            SALES
# sum  10032628.85
# min       482.13

# %%
df.groupby(['DEALSIZE','YEAR_ID', 'QTR_ID'])['SALES', 'QUANTITYORDERED'].agg(['sum','mean','std'])
# Out:
# C:\Users\84962\AppData\Local\Temp\ipykernel_17636\3902147313.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(['DEALSIZE','YEAR_ID', 'QTR_ID'])['SALES', 'QUANTITYORDERED'].agg(['sum','mean','std'])
#                               SALES                           QUANTITYORDERED  \
#                                 sum         mean          std             sum
# DEALSIZE YEAR_ID QTR_ID
# Large    2003    Q1        31364.47  7841.117500   751.541156             166
#                  Q2        89082.72  8098.429091  1239.092333             499
#                  Q3        98915.80  8242.983333  1177.767623             505
#                  Q4       213456.95  7905.812963   605.738132            1197
#          2004    Q1       110614.25  7901.017857   938.591365             627
#                  Q2        78251.84  7825.184000  1079.371923             414
# ...

# %%
pd.pivot_table(df, values= 'SALES', columns= 'YEAR_ID', aggfunc= ['mean','sum'])
# Out:
#                mean                                  sum             \
# YEAR_ID        2003        2004         2005        2003       2004
# SALES    3516.97954  3512.38855  3747.880146  3516979.54  4724162.6
#
#
# YEAR_ID        2005
# SALES    1791486.71

# %%
pd.pivot_table(df, values= ['SALES', 'QUANTITYORDERED'], columns= ['YEAR_ID','QTR_ID'], aggfunc= ['mean','sum'])
# Out:
#                         mean                                         \
# YEAR_ID                 2003
# QTR_ID                    Q1           Q2           Q3           Q4
# QUANTITYORDERED    35.084615    34.932099    33.744565    34.700382
# SALES            3423.805308  3471.390247  3529.970326  3549.628034
#
#                                                                      \
# YEAR_ID                 2004
# QTR_ID                    Q1           Q2           Q3           Q4
# QUANTITYORDERED    35.553648    34.376682    34.197492    35.026316
# SALES            3578.243262  3436.146771  3477.731254  3534.692842
#
#                                                  sum                        \
# YEAR_ID                 2005                    2003
# QTR_ID                    Q1           Q2         Q1         Q2         Q3
# QUANTITYORDERED    35.231788    39.721591    4561.00    5659.00    6209.00
# SALES            3549.643576  4088.036080  445094.69  562365.22  649514.54
#
# ...

# %%
df.groupby(['DEALSIZE', 'QTR_ID'])['SALES', 'QUANTITYORDERED'].agg(['sum',  'std', 'mean'])
# Out:
# C:\Users\84962\AppData\Local\Temp\ipykernel_17636\3754126331.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(['DEALSIZE', 'QTR_ID'])['SALES', 'QUANTITYORDERED'].agg(['sum',  'std', 'mean'])
#                       SALES                           QUANTITYORDERED  \
#                         sum          std         mean             sum
# DEALSIZE QTR_ID
# Large    Q1       259867.21   958.690868  8120.850312            1410
#          Q2       400991.68  1676.886996  8531.737872            2555
#          Q3       212533.31   986.918542  8174.358077            1120
#          Q4       428727.06  1214.335156  8244.751154            2329
# Medium   Q1      1477456.70  1014.593418  4371.173669           12763
#          Q2      1139916.85  1115.263248  4384.295577           10311
#          Q3      1048157.65   995.525905  4422.606118            8901
# ...

# %%
df.head(10)
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
# 5        10168               36      96.66                1  3479.76
# 6        10180               29      86.13                9  2497.77
# 7        10188               48     100.00                1  5512.32
# 8        10201               22      98.57                2  2168.54
# 9        10211               41     100.00               14  4708.44
#
#     ORDERDATE   STATUS QTR_ID  MONTH_ID  YEAR_ID  ...           CITY  STATE  \
# 0   2/24/2003  Shipped     Q1         2     2003  ...            NYC     NY
# ...

# %%
df[['CONTACTLASTNAME']]
# Out:
#      CONTACTLASTNAME
# 0                 Yu
# 1            Henriot
# 2           Da Cunha
# 3              Young
# 4              Brown
# ...              ...
# 2818          Freyre
# 2819       Koskitalo
# 2820          Freyre
# 2821          Roulet
# 2822         Yoshido
#
# [2823 rows x 1 columns]

# %%
name_compare = df['CONTACTLASTNAME'].str.contains('Brown')
name_compare.head(10)
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# 5    False
# 6    False
# 7    False
# 8    False
# 9    False
# Name: CONTACTLASTNAME, dtype: bool

# %%
df.describe()
# Out:
#         ORDERNUMBER  QUANTITYORDERED    PRICEEACH  ORDERLINENUMBER  \
# count   2823.000000      2823.000000  2823.000000      2823.000000
# mean   10258.725115        35.092809    83.658544         6.466171
# std       92.085478         9.741443    20.174277         4.225841
# min    10100.000000         6.000000    26.880000         1.000000
# 25%    10180.000000        27.000000    68.860000         3.000000
# 50%    10262.000000        35.000000    95.700000         6.000000
# 75%    10333.500000        43.000000   100.000000         9.000000
# max    10425.000000        97.000000   100.000000        18.000000
#
#               SALES     MONTH_ID     YEAR_ID         MSRP
# count   2823.000000  2823.000000  2823.00000  2823.000000
# mean    3553.889072     7.092455  2003.81509   100.715551
# std     1841.865106     3.656633     0.69967    40.187912
# min      482.130000     1.000000  2003.00000    33.000000
# 25%     2203.430000     4.000000  2003.00000    68.000000
# ...

# %%
import matplotlib.pyplot as plt

# %%
df['PRODUCTLINE'].value_counts().plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
df['PRODUCTLINE'].value_counts().plot(kind = 'pie')
# Out:
# <AxesSubplot:ylabel='PRODUCTLINE'>

# %%
def ftrust(x,y) :
    if x <= y :
        return 'YES'
    else: 
        return 'NO'

df['Trust'] = list(map(ftrust, df['PRICEEACH'], df['MSRP']))

# %%
df[['PRICEEACH', 'MSRP', 'Trust']]
# Out:
#       PRICEEACH  MSRP Trust
# 0         95.70    95    NO
# 1         81.35    95   YES
# 2         94.74    95   YES
# 3         83.26    95   YES
# 4        100.00    95    NO
# ...         ...   ...   ...
# 2818     100.00    54    NO
# 2819     100.00    54    NO
# 2820     100.00    54    NO
# 2821      62.24    54    NO
# 2822      65.52    54    NO
#
# [2823 rows x 3 columns]
